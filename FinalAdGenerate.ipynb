# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import faiss
import os
import pickle
import torch
import openai
from tqdm import tqdm
from transformers import BertForSequenceClassification, BertTokenizer
from sentence_transformers import SentenceTransformer

# Set up OpenAI API key
openai.api_key = 'YOUR_OPENAI_API_KEY'

# Set up device (use GPU if available)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load the sentiment analysis model and tokenizer
sentiment_model = BertForSequenceClassification.from_pretrained('sentiment_model')
sentiment_tokenizer = BertTokenizer.from_pretrained('sentiment_model')

# Move the model to the appropriate device
sentiment_model.to(device)
sentiment_model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
# Initialize the embedding model for RAG
embedding_model = SentenceTransformer('all-mpnet-base-v2')  # Or your chosen embedding model

# %%
embeddings_file = 'product_embeddings.npy'
metadata_file = 'product_metadata.pkl'
index_file = 'faiss_index.index'

if os.path.exists(embeddings_file) and os.path.exists(metadata_file) and os.path.exists(index_file):
    # Load embeddings, metadata, and index
    embeddings = np.load(embeddings_file)
    with open(metadata_file, 'rb') as f:
        metadata = pickle.load(f)
    index = faiss.read_index(index_file)
    print("Loaded embeddings and index from disk.")
else:
    # Load the dataset
    df = pd.read_csv('train.csv')  
    
    # Clean the dataset
    df_cleaned = df[['TITLE', 'BULLET_POINTS', 'DESCRIPTION']].dropna()
    df_cleaned.reset_index(drop=True, inplace=True)
    
    # Display the number of products
    print(f"Number of products in the dataset: {len(df_cleaned)}")
    
    # Compute embeddings
    print("Computing embeddings...")
    texts = [
        f"{row['TITLE']} {row['BULLET_POINTS']} {row['DESCRIPTION']}"
        for _, row in tqdm(df_cleaned.iterrows(), total=df_cleaned.shape[0])
    ]
    embeddings = embedding_model.encode(texts, batch_size=64, show_progress_bar=True)
    embeddings = np.array(embeddings).astype('float32')
    
    # Store metadata
    metadata = [
        {
            'title': row['TITLE'],
            'bullet_points': row['BULLET_POINTS'],
            'description': row['DESCRIPTION']
        }
        for _, row in df_cleaned.iterrows()
    ]
    
    # Save embeddings and metadata
    np.save(embeddings_file, embeddings)
    with open(metadata_file, 'wb') as f:
        pickle.dump(metadata, f)
    
    # Build FAISS index
    print("Building FAISS index...")
    dimension = embeddings.shape[1]
    index = faiss.IndexHNSWFlat(dimension, 32)
    faiss.normalize_L2(embeddings)
    index.add(embeddings)
    faiss.write_index(index, index_file)
    print("FAISS index built and saved to disk.")
# Out:
# Loaded embeddings and index from disk.

# %%
# Function to preprocess text
def preprocess_text(text):
    return text.lower().strip()

# Sentiment Analysis Function
def analyze_sentiment(text):
    inputs = sentiment_tokenizer(text, return_tensors="pt", max_length=512, truncation=True, padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = sentiment_model(**inputs)
    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=-1).item()
    label_map = {0: "negative", 1: "neutral", 2: "positive"}
    predicted_sentiment = label_map[predicted_class]
    return predicted_sentiment

# Function to extract key information using GPT
def extract_key_info(review):
    messages = [
        {
            "role": "system",
            "content": "You are a helpful assistant that extracts key information from product reviews."
        },
        {
            "role": "user",
            "content": (
                f"Please extract the product title and key features mentioned in the following review:\n\n"
                f"Review: \"{review}\"\n\n"
                f"1. Product Title:\n2. Key Features:"
            )
        }
    ]
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini",
        messages=messages
    )
    extracted_info = response['choices'][0]['message']['content'].strip()
    return extracted_info

# Function to retrieve product information using RAG
def retrieve_product_info(query_title, index, metadata, top_k=3):
    query_title_normalized = preprocess_text(query_title)
    query_embedding = embedding_model.encode([query_title_normalized], convert_to_numpy=True)
    query_embedding = np.array(query_embedding).astype('float32')
    faiss.normalize_L2(query_embedding)
    distances, indices = index.search(query_embedding, top_k * 5)
    initial_results = []
    for idx in indices[0]:
        product_info = metadata[idx]
        initial_results.append(product_info)
    query_tokens = set(query_title_normalized.split())
    scored_results = []
    for product_info in initial_results:
        product_title = preprocess_text(product_info['title'])
        product_tokens = set(product_title.split())
        overlap = query_tokens.intersection(product_tokens)
        score = len(overlap)
        scored_results.append((score, product_info))
    scored_results.sort(key=lambda x: x[0], reverse=True)
    results = [item[1] for item in scored_results[:top_k]]
    return results

# Function to create initial prompt based on sentiment and features
def create_ad_prompt(sentiment, features):
    if sentiment == "positive":
        prompt = (
            f"Write an enthusiastic advertisement that highlights these exceptional features: {features}. "
            f"Emphasize how these features make the product unique and beloved by customers."
        )
    elif sentiment == "negative":
        prompt = (
            f"Customers have expressed concerns about: {features}. "
            f"Create an advertisement for an upgraded product that addresses these issues. "
            f"Highlight the improvements and reassure customers by emphasizing the new benefits."
        )
    elif sentiment == "neutral":
        prompt = (
            f"Based on customer feedback regarding: {features}, "
            f"introduce a new and improved product that addresses these points. "
            f"Develop an informative advertisement that highlights the product's strengths and the enhancements made. "
            f"Provide compelling information to educate potential customers about the product's benefits."
        )
    else:
        prompt = (
            f"Generate an advertisement highlighting the key features: {features}."
        )
    return prompt

system_prompt = (
    "You are an expert marketing copywriter with a talent for crafting compelling and persuasive advertisements. "
    "Your ads should be engaging, informative, and encourage potential customers to consider purchasing the product."
)

# Function to generate final advertisement using GPT
def generate_ad(prompt, key_features, product_info):
    product_details = ""
    for info in product_info:
        title = info['title']
        bullet_points = info['bullet_points']
        description = info['description']
        product_details += f"Title: {title}\nBullet Points: {bullet_points}\nDescription: {description}\n\n"
    messages = [
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": (
                f"{prompt}\n\n"
                f"Product Information:\n{product_details}"
            )
        }
    ]
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini",
        messages=messages,
        max_tokens=350,
        temperature=0.7,
        n=1,
        stop=None
    )
    ad_text = response['choices'][0]['message']['content'].strip()
    return ad_text

# %%
import re

# Example reviews for testing (you can replace these with other reviews)
user_reviews = [
    "This tablet is incredibly slow, and the battery drains faster than I can charge it. It’s almost unusable for anything productive.",
    "I bought these sunglasses thinking they’d be durable, but the frame broke after just one drop. Not impressed with the quality.",
    "This hair dryer cuts my drying time in half, and my hair feels smoother. The heat settings are just right, and it’s lightweight too!",
    "The electric toothbrush is too aggressive on my gums, even on the gentlest setting. My gums started bleeding, so I stopped using it.",
    "The fitness tracker’s step count is way off. It’s stylish, but the tracking features are inaccurate, which defeats the purpose.",
    "These Nike shoes are super comfortable and lightweight, ideal for long runs.",
    "This stroller is impossible to maneuver. It’s heavy, clunky, and folding it up is a nightmare. I regret this purchase.",
    "The yoga mat has a horrible chemical smell that hasn’t gone away after several uses. I can’t use it without feeling nauseated.",
    "The headphones started crackling within a week. Definitely not worth the price – really disappointed with the sound quality.",
    "The mini projector is fun to use, but the image quality is quite poor. It’s okay for occasional use, but don’t expect cinema quality."
]

# Iterate over each review and run the process
for i, user_review in enumerate(user_reviews, start=1):
    print(f"Test Case {i}:")
    
    # Step 1: Sentiment Analysis
    sentiment = analyze_sentiment(user_review)
    print(f"\nPredicted Sentiment: {sentiment}")
    
    # Step 2: Extract Key Information
    extracted_info = extract_key_info(user_review)
    print(f"\nExtracted Information:\n{extracted_info}")
    
    # Parse the extracted information to get the product title and key features
    title_match = re.search(r"1\. Product Title:\s*(.*)", extracted_info)
    features_match = re.search(r"2\. Key Features:\s*(.*)", extracted_info, re.DOTALL)

    if title_match:
        product_title = title_match.group(1).strip()
    else:
        product_title = ""
    if features_match:
        key_features = features_match.group(1).strip()
    else:
        key_features = ""
    print(f"\nProduct Title: {product_title}")
    print(f"Key Features: {key_features}")
    
    # Step 3: Retrieve Product Information
    retrieved_info = retrieve_product_info(product_title, index, metadata, top_k=3)
    print("\nRetrieved Product Information:")
    for j, info in enumerate(retrieved_info):
        print(f"\nResult {j+1}:")
        print(f"Title: {info['title']}")
        print(f"Bullet Points: {info['bullet_points']}")
        print(f"Description: {info['description']}")
    
    # Step 4: Create Initial Prompt
    initial_prompt = create_ad_prompt(sentiment, key_features)
    print(f"\nInitial Prompt:\n{initial_prompt}")
    
    # Step 5: Generate Final Advertisement
    final_ad = generate_ad(initial_prompt, key_features, retrieved_info)
    print("\nGenerated Advertisement:\n")
    print(final_ad)
    print("==================================================\n")
# Out:
# Test Case 1:
# f:\LUT University\Thesis\venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:440: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Predicted Sentiment: negative
#
# Extracted Information:
# 1. Product Title: Tablet
# 2. Key Features: Slow performance, fast battery drain, unusable for productivity.
#
# Product Title: Tablet
# Key Features: Slow performance, fast battery drain, unusable for productivity.
#
# Retrieved Product Information:
#
# Result 1:
# Title: TS X1 Tablet i5 8G 256G W10P
# Bullet Points: Lenovo ThinkPad X1 Tablet 3rd Gen 20KJ0019US 13 Touchscreen LCD 2 in 1 Notebook - Intel Core i5 (8th Gen) i5-8350U Quad-core (4 Core) 1.70 GHz - 8 GB DDR4 SDRAM - 256 GB SSD - Windows 10 Pro 64-bit (English) - 3000 x 2000 - In-plane Switching (IPS) Technology - Black - Intel UHD Graphics 620 DDR4 SDRAM - Bluetooth - English (US) Keyboard - Near Field Communication - IEEE 802.11a/b/g/n/ac - Ethernet - Network (RJ-45) - USB Type-C
# Description: Tablet. Laptop. Canvas. You decide.Redesigned from the ground up, the ThinkPad X1 Tablet gives you power, productivity, and portability in an ultrapremium detachable 2-in-1 that means business. From the enlarged 13 edge-to-edge screen to the enhanced security hardware, to the responsive voice experience that wakes your device even faster, the ThinkPad X1 Tablet is the perfect solution for professionals on the go.
#
# Result 3:
# Title: Acer Iconia One 7 NT.LCJAA.001 B1-780-K610 Tablet (7 Inches) White
# Bullet Points: [Best Quality,Acer America Corp.,Original Product]
# Description: The Iconia One 7 is a compact package full of media fun. With a bigger-than-phablet display that is both clear and colorful; you get speedy response and hours of battery life to keep things going. We've also included our Kids Center platform with lots of cool kid's stuff that parents can control.
#
# Initial Prompt:
# Customers have expressed concerns about: Slow performance, fast battery drain, unusable for productivity.. Create an advertisement for an upgraded product that addresses these issues. Highlight the improvements and reassure customers by emphasizing the new benefits.
#
# Generated Advertisement:
#
# **Introducing the All-New TS X1 Tablet: Power Meets Portability!**
#
# Are you tired of sluggish performance and battery drain when you need it the most? It’s time to upgrade to the **TS X1 Tablet i5 8G 256G W10P**, your ultimate solution for productivity on the go!
#
# **Why Choose the TS X1? Here’s What’s New:**
#
# 🚀 **Lightning-Fast Performance:** Powered by the Intel Core i5 8th Gen Quad-core processor, the TS X1 Tablet ensures seamless multitasking with 8GB DDR4 RAM. Say goodbye to slowdowns and hello to efficiency!
#
# 🔋 **Extended Battery Life:** Designed with your busy lifestyle in mind, the TS X1 features an optimized battery that keeps you connected longer. No more worrying about your device dying in the middle of an important task!
#
# 💻 **Versatile 2-in-1 Design:** Transition effortlessly between tablet and laptop modes with a stunning 13-inch edge-to-edge touchscreen. Whether you’re drafting reports, making presentations, or enjoying your favorite media, the TS X1 adapts to your needs.
#
# 🌟 **Brilliant Display & Graphics:** Experience vibrant visuals with a 3000 x 2000 resolution and IPS technology that brings your content to life. Perfect for both work and play!
#
# 🔒 **Enhanced Security Features:** Keep your data safe with advanced security hardware. The TS X1 Tablet not only protects your information but gives you peace of mind while you work.
#
# 🖱️ **Incredibly Responsive:** With a voice-activated experience, wake up your device faster than ever. It’s all about efficiency and making your life easier!
#
# **Perfect for Professionals on the Go:** No
# ==================================================
#
# Test Case 2:
#
# Predicted Sentiment: negative
#
# Extracted Information:
# 1. Product Title: Sunglasses
# 2. Key Features: Durability, quality (with a negative impression on the quality)
#
# Product Title: Sunglasses
# Key Features: Durability, quality (with a negative impression on the quality)
#
# Retrieved Product Information:
#
# Result 1:
# Title: IDOR Fashionable Round Style Sunglasses for Men & Boys | 3362-C38
# Bullet Points: [Material: Alloy,Style: Round,Frame Structure: Full Rim,Lens Type: UV Protection,Material & Care: Remove dust and grime by gently wiping the lens with a cloth.,Warranty Type: 6 Months]
# Description: Buy Cool Trendy Fashionable Sunglasses | Goggles | shades. All sunglasses are made using top-notch materials. Sunglasses are ideal for getting a charge out of the daylight, travelling, driving, fishing or shopping. Show your unique and top-of-the-line i.e. high-end taste with the sunglasses. What's more, these shades are lightly weighted to enable you long time wearing them without fatigue. Product features are - easy to clean, lightweight, durable, reduces reflections and glare, reduces eyestrain, no tired eyes after a full day in the sun, improved contrast, and visual clarity to provide you with a clear vision. These sunglasses are not just stylish, but lightweight and durable as well. Ideal for daily wear, these sunglasses will keep your eyes well shielded from harsh sun rays, and protect your eyes against harmful UVA/UVB & UVC rays, minimizing damage to your eyesight, in the long run. To avoid damage, never clean your sunglasses with Pedder towels or clothing, and also avoid using household detergents or soaps. While a few mild sodas don't harm lenses but extra-strength sodas are powerful enough to slowly disintegrate lens coatings.
#
# 💨 **Lightweight Design for Effortless Styling!**
# No more arm fatigue! The Nova N-6130 is designed with your comfort in mind, making it incredibly lightweight and easy to maneuver. Style your hair without the strain—perfect for those busy mornings or last-minute touch-ups!
#
# With a **foldable handle** for easy storage and a **cool shot feature** to lock in your look, the Nova N-6130 is not just a hair dryer; it’s a game-changer that enhances your daily routine.
#
# Join the countless satisfied customers who have made the Nova N
# ==================================================
#
# Test Case 4:
#
# Predicted Sentiment: negative
#
# Extracted Information:
# 1. Product Title: Electric Toothbrush
# 2. Key Features: Aggressive on gums, gentlest setting available, causes gum bleeding.
#
# Product Title: Electric Toothbrush
# Key Features: Aggressive on gums, gentlest setting available, causes gum bleeding.
#
# Retrieved Product Information:
#
# Result 1:
# Title: Rotary Cleaning Electric Toothbrush Waterproof Strong Adult Electric Toothbrush with 4 Duponts Heads Sonic Electric Toothbrush(purple)
# Bullet Points: [SONIC CLEANING - Electric toothbrush with the latest sonic technology that injects fluid deep between teeth and along the gumline for exceptional cleaning and 100% plaque removal, whitening teeth and improving oral health better than a manual toothbrush in two weeks .,TRAVEL PARTNER - Effectively removes up to 100% more surface discoloration than a manual toothbrush. Enjoy healthy teeth in just 14 days. Get a deep, deep clean with less noise but a powerful overall improvement over other regular electric toothbrushes. Ergonomically integrated handle, waterproof, for showering.,SAVE EFFORT AND TIME - The toothbrush vibrates or spins in the cavity when in use, and users just have to stretch by hand instead of using force, so it's a good electric rechargeable toothbrush for a business trip or family trip!,High Vibration Frequency - Vibration frequency 6000 times per minute for effective cleaning of the oral cavity. The rounded bristles on the head can protect the gums and not harm the mouth. Use every morning and evening for two minutes to effectively remove tartar.,4 REPLACEMENT BRUSH HEADS - Comes with 4 interchangeable brush heads to avoid frequent ordering of new replacement brush heads. It is a tailored tooth topography for thorough cleaning of gums and hard-to-reach places. Note: Each brush head will last for 3 months, so 4 will last for around 12 months.]
# Description: <p> <b> Function: </b> </p> <p> 1. Use every morning and evening for two minutes to effectively remove tartar. <br/> 2. Waterproof toothbrush design, but avoid long-term immersion in water to extend the use time. <br/> 3. The toothbrush vibrates or rotates in the cavity during use, and users just need to stretch their hand instead of using force. <br/> 4. The rounded bristles on the head can protect the gums and not damage the mouth. <br/> 5. Vibration frequency 6000 times per minute for effective cleaning of the oral cavity. </p> <p> <br/> </p> <p> <b> Specification: </b> </p> <p> <br/> </p> <p> <br/> </p> <p> Condition: 100% Brand New <br/> Item Type: Electric Toothbrush <br/> Material: ABS <br/> Battery: 2pcs AA (not included) <br/> Rotating left and right to clean teeth and remove tartar more effectively than a manual toothbrush, and makes the teeth cleaner and whiter </p> <p> <br/> </p> <p> <br/> </p> <p> <br/> </p> <p> <b> Package list: </b> </p> <p> 1 x toothbrush </p> <p> 4 x toothbrush head </p> <p> 1 x base </p>
#
# Result 2:
# Title: Kids Electric Toothbrushes, U Shaped Ultrasonic Autobrush Toothbrush, Rechargeable Kids Toothbrush, with 2 Brush Heads, Bring a Mouthwash Cup |Smart Timer| IPX7 Waterproof, Toddler Toothbrush Age 2-6
# Bullet Points: [[Excellent Battery] Our electric toothbrush is powered by a rechargeable battery with a lifespan of 25-30 days after only 10 hours of USB charging. Never worry about needing to charge while traveling.,[Two-Minute Smart Timer] The Electric toothbrush has a built-in timer that causes it to pause every 30 seconds to let you know it’s time to move to the next quadrant of your mouth. There are 3 pauses separating 4 brushing periods for a total of 2 minutes,[Use in the shower] IPX7 technology makes brushing teeth easier while taking a shower. It perfectly solves the problem of having the battery damaged by water- it’s no problem with this model,[2 Brush Heads] Two toothbrush heads are included. One purchase lasts at least 6 months,[Advanced Sonic Tech] Our sonic electric toothbrush vibrates up to 20,000-30,000 times per minute providing comfortable and effective oral care]
# Description: Product includes: <br> 1 * Electronic Toothbrush Handle<br> 3 * Brush<br> 1 * USB Cable<br> 1 * Manual<br> <br> <br> Handle dimension: 1.1*1.1*9.8 inch<br> Weight (brush+handle): 1.3 oz<br> Charging time: 10 hours
#
# Initial Prompt:
# Customers have expressed concerns about: Aggressive on gums, gentlest setting available, causes gum bleeding.. Create an advertisement for an upgraded product that addresses these issues. Highlight the improvements and reassure customers by emphasizing the new benefits.
#
# Generated Advertisement:
#
# ### Transform Your Smile with Our Upgraded Rotary Cleaning Electric Toothbrush!
#
# Introducing the **Rotary Cleaning Electric Toothbrush**—the ultimate solution for anyone seeking a gentler, yet highly effective oral care routine! We’ve listened to your concerns and made significant improvements to ensure your brushing experience is not only effective but also comfortable and safe for your gums.
#
# #### **Key Improvements:**
#
# - **Gentle on Gums:** Our newly designed **rounded bristles** are specifically crafted to protect your gums, providing a soft touch while still delivering a powerful clean. Say goodbye to gum bleeding and discomfort!
#
# - **Optimized Sonic Technology:** Our advanced **sonic cleaning technology** now injects fluid deep between teeth and along the gumline, ensuring **100% plaque removal** while being gentle enough for sensitive gums. Experience a brighter smile and improved oral health in just two weeks!
#
# - **Travel-Friendly Design:** Take your dental hygiene on the go! This waterproof toothbrush is perfect for travel and can be used in the shower. Enjoy a deep clean without the noise, making it a discreet companion on your business or family trips.
#
# - **User-Friendly Features:** With a **high vibration frequency of 6000 times per minute**, this toothbrush vibrates or spins effortlessly, requiring minimal effort from you. Brush just two minutes every morning and evening for optimal oral hygiene.
#
# - **4 Replacement Brush Heads Included:** Never worry about running out of brush heads again! Our toothbrush comes with **4 interchangeable brush heads**, each lasting up to 3 months. That's a full year of top-notch dental care!
#
# #### **Why Choose Our Upgraded Toothbrush?**
#
# - **No More Gum Bleeding:** Our design prioritizes your gum health, allowing you to brush confidently without
# ==================================================
#
# Test Case 5:
#
# Predicted Sentiment: negative
#
# Extracted Information:
# 1. Product Title: Fitness Tracker
# 2. Key Features: Stylish design, inaccurate step count, poor tracking features
#
# Product Title: Fitness Tracker
# Key Features: Stylish design, inaccurate step count, poor tracking features
#
# Retrieved Product Information:
#
# Result 1:
# Title: Fitness Tracker Watch, Activity Tracker Smart Watch Waterproof Smartwatch Color Screen with Heart Rate Monitor Bracelet Pedometer Step Counter and Sleep Monitor Calorie for iOS Android iPhone
# Bullet Points: [【New Style Fitness Tracker Watch for Sports】: Heart rate monitor, 8 Sport modes, sleep monitor, stopwatch, sedentary alert, step count, calorie burned, mileage detection and weather information. 8 Sport modes include walking, running, cycling, skipping, badminton, basketball, football, swimming.,【Heart Rate Monitor and Sleep Tracking】Continuous, automatic, wrist-based heart rate tracking without an uncomfortable chest strap, it can help you better understand your health and fitness. Automatically tracks your sleep duration and sleep stages.,【Never Miss a Message/Call】: The Tracker Watch will vibrate to alert you if your phone receives a phone call, SMS text and SNS messages including Facebook, Twitter, WhatsApp, Linkedin, Messenger, etc. Simply connect the smart watch to your smart phone via Bluetooth and set in the 'Da Fit'app, you will never miss a call and a message.,【Waterproof and Color Screen】: Waterproof IP67, 1.3-inch TFT full-color IPS display, all data can be perfectly displayed on the color screen, the fitness watch is very easy to touch and operate.,【Applicable Models and Remote Control Phone Camera, Music】: Bluetooth 4.0, Android 4.4/iOS 9.0 and higher models. After connecting the smartwatch, you can remote control phone camera and music play.]
# Description: <p>&nbsp;smart watch</p><p>A smart watch that deserves your long-term ownership.</p><p></p><p>A nice watch with different dials to choose from;</p><p></p><p>A good watch, check the message, remind the call, take a picture from a distance;</p><p></p><p>A healthy watch, automatic sleep monitoring, recording of data during exercise;</p><p></p><p>An unloaded watch with long battery life</p>
#
# Result 2:
# Title: Fun Jungle Fitness Tracker ID115 Plus HR, Heart Rate Watch, Color Screen, Activity Tracker HR, Sleep Monitor Smart, Bracelet Pedometer for Kids, Women and Men, for Android iOS (Blue)
# Bullet Points: [Note: Don't need the usb charger cable. Track your daily steps, calorie consumed, distance, monitor continuous heart rate, record the duration of exercise, average pace. Show the notification of the incoming call, message and SNS from Social Media Software.,Monitor your daily sleep quality, tell you how long and how well you sleep during the night. Set alarm and sedentary alert can silently remind you to wake up, take medicine or do some exercise.,Map your sports route in the app by following the connected GPS tracker, you can see average speed, activity distance, workout route, energy consumption in the app. (Only for walking and running.),0.96 big OLED Screen with 4 customized clock faces. Comfortable, fashionable, adjustable anti-lost strap for lovely kids, sporty men and business men.,14 sports modes for specific activity can meet your needs the whole day. 24-hour real-time continuous heart rate can give you tips for exercise. Support Android 4.4 and above, iOS 7.1 and above only for smartphone]
# Description: <strong>FUN JUNGLE Fitness Activity Tracker Pedometer Remote Camera OLED IP67 USB Charge Smart Band ID115 Plus</strong><br><br>OS Support: it works with most phones in Android 4.4 or above/ iOS 7.1 or above.<br><strong>KEY FEATURES:</strong><br>0.96 inch large screen<br>Five-day standby<br>Heart rate monitor<br>Sleep quality monitor<br>Connected gps function<br>Track 14 sports modes<br>Want to get fit and strong? Just listen to your heart!<br>Adopting the newest optical sensor to monitor the heart rate, chart your heart rate data.<br>Want to get healthy and energetic ? Just have a good sleep!<br>Monitor your sleep quality more accurately by adopting the accelerometer and analyzing the heart rate.<br>Want to do more interesting activities? Just try this!<br>Built-in 8 sports modes, additional 6 sports modes in the app.<br>We know you wanna make sports more fun, this version is added connected GPS function.<br>You can create your trajectory to any shape in the app.<br>Today's ranking list can help you better know other competitors. (Don't support team competition.)<br>Once connected with the app, the functions of wristband are more than expected.<br>Additional Features:<br>Remote camera control<br>No Disturb Mode<br>Four clock faces available<br>Message and call notification<br>IP67 Life-level waterproof and dustproof<br>Band: TPU material, very comfortable and adjustable anti-lost stra
# Description: <p>At TRENDY-PRO our main focus is FAMILY.&nbsp;Our commitment to the exceptional customer service and relentless continuous improvement based on your feedback set us apart.<br /> We understand that maintaining a healthy activity level is not easy, especially when it comes to kids, so we have created Reward Charts to encourage your family to stay active.&nbsp;We have listened to your feedback and created a User Guide that covers Features, tips and FAQ that will be sent to you via email. Also, to make your initial set up easier, a Video is available in the Relevant Videos Section below. It was created based on customers request for a Kids-friendly User Guide. It's made by the kids for the kids!</p> <p><strong>Activity Tracking: </strong>Steps, distance, calories burned and your daily activities</p> <p><strong>Sleep Tracking: </strong>Tracking how long and how deep is your sleep. Stats include light sleep, deep sleep and duration awake</p> <p><strong>Silent Alarms: </strong>You can set up to 10 alarms in the App and your Tracker will vibrate to wake you</p> <p><strong>Sedentary reminders: </strong>Your Tracker will give you reminders to stay active throughout the day</p> <p><strong>Call, Text &amp; Social App Alerts: </strong>See alerts for incoming calls, text messages, notifications from Facebook, Whatsapp, Twitter, Instagram and more</p> <p><strong>Remote Camera Control: </strong>Take photos with your phone using your Tracker to trigger the shot remotely</p> <p><strong>Anti-Lost: </strong>Alert if you move more than 5m away from your cell</p> <p><strong>Find Phone: </strong>Use your Tracker to trigger an audio alert on your phone to locate it</p> <p><strong>Compatibility </strong></p> <p><strong>Apple: </strong>Apple iPhone 4s, iPad 3rd Gen, iPod Touch 5th Gen &amp; above</p> <p>OS: Apple iOS 7.1 &amp; above</p> <p><strong>Android phones: </strong>OS: Android 4.5 &amp; above</p> <p>Bluetooth v4.0</p> <p>&nbsp;Stay healthy and happy with TRENDY-PRO!</p>
#
# Initial Prompt:
# Customers have expressed concerns about: Stylish design, inaccurate step count, poor tracking features. Create an advertisement for an upgraded product that addresses these issues. Highlight the improvements and reassure customers by emphasizing the new benefits.
#
# Generated Advertisement:
#
# **Introducing the All-New Trendy-Pro Fitness Tracker Watch: Your Ultimate Health Companion!**
#
# Are you ready to elevate your fitness journey? Say goodbye to the limitations of ordinary fitness trackers and welcome the upgraded **Trendy-Pro Fitness Tracker Watch**! Designed with style, precision, and functionality in mind, our latest model addresses your concerns and takes your health monitoring to the next level.
#
# **✨ Stylish Design:**
# With a sleek and modern look, our fitness tracker is not just a tool—it's a fashion statement! Choose from multiple customizable dials to match your mood and outfit. Whether you're at the gym or out on the town, you'll look great while staying fit.
#
# **📊 Accurate Tracking Features:**
# We understand that accuracy is key to achieving your fitness goals. Our advanced sensors provide real-time heart rate monitoring and step counting, ensuring that you receive precise data every time you work out. Experience unmatched reliability with our upgraded algorithms that track your activity with pinpoint accuracy.
#
# **🏊 Waterproof & Durable:**
# Whether you’re swimming, running in the rain, or just washing your hands, the Trendy-Pro Fitness Tracker is designed to withstand it all. With an IP67 waterproof rating, you can dive into your fitness routine without fear!
#
# **💤 Enhanced Sleep Monitoring:**
# Unlock the mystery of your sleep patterns with our automatic sleep tracking feature. Gain insights into your sleep quality and duration, helping you wake up refreshed and ready to seize the day!
#
# **📱 Stay Connected:**
# Never miss a beat! Receive notifications for calls, texts, and social media alerts right on your wrist. With a gentle vibration, you’ll stay connected without the hassle of constantly checking your phone.
#
# **🏃 8 Sport Modes for Every Activity:**
# From
# ==================================================
#
# Test Case 6:
#
# Predicted Sentiment: positive
#
# Extracted Information:
# 1. Product Title: Nike Shoes
# 2. Key Features: Comfortable, lightweight, ideal for long runs
#
# Product Title: Nike Shoes
# Key Features: Comfortable, lightweight, ideal for long runs
#
# Retrieved Product Information:
#
# 2. Key Features: Heavy, clunky, difficult to maneuver, challenging to fold.
#
# Product Title: Stroller
# ...
#
# Initial Prompt:
# Customers have expressed concerns about: Chemical smell, persistent odor after several uses, causes nausea.. Create an advertisement for an upgraded product that addresses these issues. Highlight the improvements and reassure customers by emphasizing the new benefits.
#
# Generated Advertisement:
#
# **Elevate Your Practice with the Upgraded YOGA DESIGN LAB Combo Yoga Mat!**
#
# 🌟 **Say Goodbye to Odors and Hello to Comfort!** 🌟
#
# Are you tired of yoga mats that leave you feeling nauseous due to toxic smells? We heard you, and we’ve taken your feedback to heart! Introducing the **upgraded YOGA DESIGN LAB Combo Yoga Mat**—the perfect blend of luxury, performance, and eco-friendliness.
#
# ### **Key Improvements:**
#
# - **Zero Odor Guarantee:** Our new and improved design features **natural tree rubber** and **recycled microfiber** that eliminates harmful chemicals and unpleasant smells. Enjoy your practice without distractions!
#
# - **Ultra-Absorbent & Non-Slip:** The innovative 2-in-1 mat and towel design now offers even better sweat management. No more slipping or sliding—just pure stability as you flow through your poses.
#
# - **Machine Washable & Quick Dry:** Keep your mat fresh with ease! Toss it in the washing machine, and it’s ready to roll again in no time.
#
# ### **Unmatched Benefits:**
#
# - **Eco-Friendly Materials:** We care for our planet as much as you do! Made from **recycled materials and water-based prints**, our mat supports sustainability while delivering studio-quality performance.
#
# - **Comfort & Support:** Experience the ultimate in cushion and stability with our extra-comfy 3.5mm thick mat—ideal for all types of yoga, including hot yoga, ashtanga, and pilates.
#
# - **Durable & Versatile:** Lightweight, flexible, and reversible, this mat is designed for everyone—from beginners to seasoned yogis. Plus, it comes with a **durable carrying strap**
# ==================================================
#
# Test Case 9:
#
# Predicted Sentiment: negative
#
# Extracted Information:
# 1. Product Title: Headphones
# 2. Key Features: Sound quality issues, crackling sound, overpriced
#
# Product Title: Headphones
# Key Features: Sound quality issues, crackling sound, overpriced
#
# Retrieved Product Information:
#
# Result 1:
# Title: Sports in-Ear Bluetooth Neckband Earphone with Mic For Coolpad Rogue Bluetooth 5.0 Wireless Headphones with Hi-Fi Stereo Sound, 6Hrs Playtime, Lightweight Ergonomic Neckband, Sweat-Resistant Magnetic Earbuds, Voice Assistant & Mic - (ZD2,W-TONIC, Black)
# Bullet Points: [Over-ear headphones provide comfort, quality, and style.,The Handsfree With Remote Note Enjoy your music and calls with our one of the most luxurious Hands Free in the international market. Introducing its elegant Luxury Flex Grip connection prevents cable damage Perfect headset for disturbance free experience Maximum comfort and super performance Excellent for interactive games Compatible with Phone & All 3.5 mm audio jack devices.,Lightweight and comfortable, this enables you to carry on conversations while you continue to do other things.,Powerful, bass-driven stereo sound, Excellent Sound Quality,With Full Supported Mic, This headset comes with an in-line mic with remote function so you can answer/end calls without pulling out your phone.,The Black color adds style and the lightweight design with Great sound quality and bass response.]
# Description: Enjoy High Definition Sound Music with the Bluetooth Stereo Earphones which lets you take the advantage of listening music and sound, offering the best of both the worlds. The Headset lets you enjoy wireless music via Bluetooth.clearer voice transmission and superior sound quality to give you real HD music enjoyment with perfect sound quality. Stereo headphone with microphone high definition sound gives you the best sonic sound experience.
#
# Result 2:
# - **Longer Playtime**: With an upgraded battery, enjoy up to **6 hours** of uninterrupted playtime. Perfect for those long workouts or commutes!
# - **Affordable Luxury**: Experience premium quality without breaking the bank. We’ve redefined value, ensuring you receive the best sound without the hefty price tag.
# - **Ergonomic Comfort**: Designed for all-day wear, the lightweight neckband and sweat-resistant magnetic earbuds ensure a comfortable fit. You can easily carry on conversations or enjoy your favorite tunes while on the move.
#
# **🎶 Key Features:**
# - **Bluetooth 5.0 Technology**: Enjoy a stable connection with seamless pairing to your device for hassle-free listening.
# - **Voice Assistant Compatibility**: Effortlessly control your music and calls with just your voice.
# - **Stylish Design**: The sleek black finish
# ==================================================
#
# Test Case 10:
#
# Predicted Sentiment: neutral
#
# Extracted Information:
# 1. Product Title: Mini Projector
# 2. Key Features: Fun to use, poor image quality, suitable for occasional use, not cinema quality.
#
# Product Title: Mini Projector
# Key Features: Fun to use, poor image quality, suitable for occasional use, not cinema quality.
#
# Retrieved Product Information:
#
# Result 1:
# Title: Mini LED Projector LCD Multimedia Beamer Home VGA AV TF USB HDMI Support
# Bullet Points: Deevoir Mini LED Projector LCD Multimedia Beamer Home VGA AV TF USB HDMI Support
# Description: Budget Video Projector with 1.67 Million Colors projection, 200:1 contrast ratio, Coaxial TV Input and more. Get a great video projector without breaking the bank. The “ProView” Video Projector is the perfect blend between portable, good quality images and a low priced video projector. Suitable for various types of use, this video projector lends itself well as a home theater projector, letting you watch movies up to a 100 inch wide. But even in the office the “ProView” will perform well. Ultra portable, the “ProView” can quickly be moved from one room to another or even be taken with you on business meetings. Coming with a whole array of ports such as an HDMI port, an AV Port, VGA and more, all your devices will be able to connect to this video projector and you’ll even be able to hook up your TV cable to the “ProView” and watch TV in your living room on a larger than life projection. Furthermore, the “ProView” features a Micro SD card slot from which you can load movies and music and display it through the projector.
#
# Result 2:
# Title: Sanyipace Mini Projector, LED Pico Projector, Pocket Video Projector Support HDMI Smartphone PC Laptop USB for Movie Games（Blue）
# Bullet Points: [🎁 [Portable Design] most popular Mini projector is small in size ( 5. 3*3. 9*2. 36 inches/0. 59 lbs), equal a 6.5-inch smartphone, unique design makes it easier to take to anywhere.,🎀 [Rich Interfance] This compact video projector is equipped with multiple ports for ease of use, including HDMI, USB, Micro SD card, audio and AV interface. You can also show the photos and videos on a USB flash drive, firestick or micro SD. Use an HDMI Adaptor to project your smartphone easily(not include).,🎁 [Flexible Projection] home theater projector supports 1920*1080 resolution with 30,000 hours long term lamp life. Offer 20-60inches project size and 0. 8M-2.0M projection distance, giving you a clear frame and a projection size of up to 60 inches. Best gift for your family & friend, also popular with children!,🎀 [Easy Setup & Built-in Speaker] Just plug in & play. Mini movie projector is easy to use. Built-in powerful speaker can deliver a clear sound which will meet your daily needs, such as play movies and games also inspire children learning interest.,🎁 [No worry ] provides 18 months for the projector. If you're not completely satisfied with the order, please contact us via Amazon and you'll be offered a refund or replacement alternatively within the first 2 months. Absolutely risk -free purchase for you!]
# Description: <p>launched the ultra mini size of projector in the first time! Allows you to take it to anywhere,play whatever you want just you like!</p> <p>Adopt new generaton LED light source bulb which is more energy-saving than LCD projector, it is good for children teaching and protect eyes from harm.</p> <p>Built-in speakers offer excellent loud sound quality, you can also connect it to external speakers to meet your higher quality sound wants.</p> <p>tech</p> <p>Advanced Feature</p> <p>Mini size: 5.3*3.9*2.36 inches</p> <p>Lightweight: 0.59 lbs</p> <p>Project Size: 24-60"</p> <p></p> <p></p> <p>Package Included</p> <p>1x GooDee mini projector</p> <p>1x Power cable</p> <p>1x HDMI cable</p> <p>1x AV cable</p> <p>1x Remote Control ( Battery not included)</p> <p>1x User Manual</p>
#
# Result 3:
# Title: Mini Portable Projector Video & Cinema Home Theater ProjectorHDMI, USB & VGA Inputs for TV PC
# Bullet Points: [projector is equipped with multiple ports and is easy to use, including built-in HDMI, USB, TF card, VGA and AV interfaces.,for watching movies and TV shows, viewing photo slideshows and playing video games, this portable projector has excellent product performance,you can cannect this TV stick, as well as game consoles, PCs, smartphones, tablets, laptops, DVD players, Micro SD cards and USB flash drives,Our Video Movie Projector Supporting 1920X1080 source playback,,Full HD 1080p Mini Portable Projection Size up to 120'' inches User Friendly use to sata box esy]
# Description: Full HD 1080p Mini Portable Pocket Video & Cinema Home Theater Projector， LCD+LED Lamp, Digital Multimedia, HDMI, USB & VGA Inputs for TV PC Game Business Computer & Laptop projector is equipped with multiple ports and is easy to use, including built-in HDMI, USB, TF card, VGA and AV interfaces. You can connect this projector directly to your TV stick, as well as game consoles, PCs, smartphones, tablets, laptops, DVD players, Micro SD cards and USB flash drives.for watching movies and TV shows, viewing photo slideshows and playing video games, this portable projector has excellent product performance
#
# Initial Prompt:
# Based on customer feedback regarding: Fun to use, poor image quality, suitable for occasional use, not cinema quality., introduce a new and improved product that addresses these points. Develop an informative advertisement that highlights the product's strengths and the enhancements made. Provide compelling information to educate potential customers about the product's benefits.
#
# Generated Advertisement:
#
# ### Introducing the ProView Mini LED Projector: Your Gateway to Big Screen Fun!
#
# 🎥 **Transform Your Viewing Experience!** 🎥
#
# Say goodbye to mediocre image quality and hello to the new **ProView Mini LED Projector**! We've taken your feedback to heart and enhanced every aspect of our projector to deliver an unforgettable home theater experience—all while keeping it portable and budget-friendly.
#
# #### **Why Choose the ProView Mini LED Projector?**
#
# **1. Stunning Image Quality:**
# - **Vibrant Colors:** With 1.67 million colors and a 200:1 contrast ratio, enjoy sharp, clear images that bring your favorite movies and games to life!
# - **Full HD 1080p Support:** Experience cinema-quality visuals right at home, with support for 1920x1080 resolution—perfect for movie nights or game marathons.
#
# **2. Versatile & Portable Design:**
# - **Ultra-Portable:** Weighing just 0.59 lbs and measuring 5.3 x 3.9 x 2.36 inches, the ProView is designed for easy transport. Whether you’re heading to a friend’s house or a business meeting, take your entertainment with you!
# - **Flexible Projection Sizes:** Project images from 20” to 100” to fit any room size or occasion. Enjoy a big screen experience in your living room or backyard!
#
# **3. Effortless Connectivity:**
# - **Rich Interface Options:** Equipped with HDMI, USB, AV, TF card, and VGA ports, the ProView connects seamlessly with all your favorite devices—be it a smartphone, laptop, or game console.
# - **Micro SD Card Slot:** Load your favorite movies and music
# ==================================================
